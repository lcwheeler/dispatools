# %%
from dispatools import optimize_rotation_rms

# %% [markdown]
# ### Demonstration of optimizing rotation in DISPA space to find phase shift

# %%
# Set path variables to the example datasets
d0p = "../example_data/OnePeak/1000/pdata/1"
d90p = "../example_data/OnePeak/1090/pdata/1"

tp0 = "../example_data/TwoPeaks/2000/pdata/1"
tp90 = "../example_data/TwoPeaks/2090/pdata/1"

# %%
# Run the RMSE minimization algorithm to find phase shift in simulated one-peak data with 90-degree shift
best_angle, min_rms, angles_deg, rms_values, data_rotated = optimize_rotation_rms(data_path1=d0p, data_path2=d90p, ppm_region=(-0.5,0.5), step_deg=1, 
                                                                    plot=True, plotname="one-peak-0-90-phase-shift",angle_range=(-360,0))

# %%
best_angle, min_rms, angles_deg, rms_values, data_rotated = optimize_rotation_rms(data_path1=tp0, data_path2=tp90, ppm_region=(0.15,0.21), step_deg=1, 
                                                                    plot=True, plotname="two-peaks-0-90-phase-shift",angle_range=(-360,0))
